# %% [markdown]
# # 02 - Modeling
# Train and compare class-balanced logistic regression with XGBoost.

# %%
from pathlib import Path
from src.train_model import train

train(Path('../data/stroke_prediction.csv'), Path('../outputs'))
