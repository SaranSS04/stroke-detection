# %% [markdown]
# # 03 - Calibration and Explainability
# Calibrate the primary XGBoost probabilities with isotonic regression and generate a SHAP summary.

# %%
from pathlib import Path
from src.calibrate import calibrate
from src.explain import explain

output_dir = Path('../outputs')
calibrate(output_dir)
explain(Path('../data/stroke_prediction.csv'), output_dir / 'model.pkl', output_dir)
