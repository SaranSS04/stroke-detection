# %% [markdown]
# # 01 - Preprocessing
# Load the raw data, drop the non-predictive `id`, inspect class balance, and create stratified splits.

# %%
from pathlib import Path
from src.preprocessing import load_data, split_data

features, target, ids = load_data(Path('../data/stroke_prediction.csv'))
splits = split_data(features, target, ids)
print(features.shape)
print(target.value_counts(normalize=True))
