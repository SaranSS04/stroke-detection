# %% [markdown]
# # 04 - Evaluation and Abstention
# Inspect the handoff predictions and evaluate performance as the system abstains on uncertain cases.

# %%
from pathlib import Path
from src.abstention import generate

generate(Path('../outputs'))
